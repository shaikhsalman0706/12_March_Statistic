# %% [markdown]
# ### Q1. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5 using Python. Interpret the results.

# %%
import statistics as stats

data = [49, 52, 48, 51, 50]  # sample data
n = len(data)  # sample size
mean = stats.mean(data)  # sample mean
std = stats.stdev(data)  # sample standard deviation

conf_int = st.t.interval(0.95, df=n-1, loc=mean, scale=std / n**0.5)
print("95% confidence interval:", conf_int)
# Out:
# 95% confidence interval: (48.036756838522436, 51.963243161477564)

# %% [markdown]
# ### Q2. Conduct a chi-square goodness of fit test to determine if the distribution of colors of M&Ms in a bag matches the expected distribution of 20% blue, 20% orange, 20% green, 10% yellow, 10% red, and 20% brown. Use Python to perform the test with a significance level of 0.05.

# %% [markdown]
# #### To conduct a chi-square goodness of fit test in Python, we can use the chisquare function from the scipy.stats module. Here's an example of how to perform the test for the M&M's bag:

# %%
import scipy.stats as stats

observed = [110, 100, 80, 60, 50, 100]  # observed counts for each color
expected = [0.2, 0.2, 0.2, 0.1, 0.1, 0.2]  # expected proportions for each color

# calculate expected counts based on the expected proportions and the sample size
n = sum(observed)
expected_counts = [prop * n for prop in expected]

# perform the chi-square test
chi2_stat, p_val = stats.chisquare(observed, f_exp=expected_counts)

# compare p-value to significance level to determine if the results are significant
alpha = 0.05
if p_val < alpha:
    print("The results are significant. The distribution of colors in the bag is different from the expected distribution.")
else:
    print("The results are not significant. The distribution of colors in the bag is not significantly different from the expected distribution.")

# print the chi-square statistic and p-value
print("Chi-square statistic:", chi2_stat)
print("P-value:", p_val)
# Out:
# The results are not significant. The distribution of colors in the bag is not significantly different from the expected distribution.
# Chi-square statistic: 7.0
# P-value: 0.22064030793671066

# %% [markdown]
# #### In this example, we first define the observed counts for each color as observed and the expected proportions for each color as expected. We then calculate the expected counts based on the expected proportions and the sample size.
#
# #### Next, we use the chisquare function to perform the chi-square test. We pass in the observed counts and the expected counts as arguments to the chisquare function. The function returns the chi-square statistic and the p-value.
#
# #### Finally, we compare the p-value to the significance level (0.05) to determine if the results are significant. If the p-value is less than the significance level, we reject the null hypothesis and conclude that the distribution of colors in the bag is different from the expected distribution. If the p-value is greater than or equal to the significance level, we fail to reject the null hypothesis and conclude that there is not enough evidence to suggest that the distribution of colors in the bag is different from the expected distribution.

# %% [markdown]
# ### Q3. Use Python to calculate the chi-square statistic and p-value for a contingency table with the following data:
# ![Screenshot%202023-03-17%20091045.jpg](attachment:Screenshot%202023-03-17%20091045.jpg)
# ### Interpret the results of the test.

# %%
from scipy.stats import chi2_contingency

# create the contingency table
observed = [[20, 15], [10, 25], [15, 20]]

# calculate the chi-square statistic, p-value, degrees of freedom, and expected frequencies
chi2_stat, p_val, dof, expected = chi2_contingency(observed)

# print the results
print("Chi-square statistic: ", chi2_stat)
print("P-value: ", p_val)
# Out:
# Chi-square statistic:  5.833333333333334
# P-value:  0.05411376622282158

# %% [markdown]
# #### Based on the calculated chi-square statistic of 5.83 and the corresponding p-value of 0.054, we can interpret that there is weak evidence to reject the null hypothesis of independence. This means that we cannot conclude that there is a significant association between the outcomes and the groups. However, since the p-value is close to the significance level of 0.05, it is recommended to further investigate the data or to increase the sample size to obtain more conclusive results.

# %% [markdown]
# ### Q4. A study of the prevalence of smoking in a population of 500 individuals found that 60 individuals smoked. Use Python to calculate the 95% confidence interval for the true proportion of individuals in the population who smoke.

# %%
from statsmodels.stats.proportion import proportion_confint

n = 500
p = 60/500

lower, upper = proportion_confint(count=p*n, nobs=n, alpha=0.05, method='wilson')

print("95% confidence interval:", (lower, upper))
# Out:
# 95% confidence interval: (0.09437490012636912, 0.1514195986244106)

# %% [markdown]
# ###### Interpretation: We are 95% confident that the true proportion of individuals in the population who smoke is between 0.094 and 0.151.

# %% [markdown]
# ### Q5. Calculate the 90% confidence interval for a sample of data with a mean of 75 and a standard deviation of 12 using Python. Interpret the results.

# %%
import scipy.stats as stats

sample_mean = 75
sample_std = 12
n = 100

z = stats.norm.ppf(0.95)
margin_of_error = z * (sample_std / n**(1/2))

lower_bound = sample_mean - margin_of_error
upper_bound = sample_mean + margin_of_error

print("90% Confidence Interval: ({:.2f}, {:.2f})".format(lower_bound, upper_bound))
# Out:
# 90% Confidence Interval: (73.03, 76.97)

# %% [markdown]
# ###### Interpretation:
# #### We are 90% confident that the true population mean lies between 73.03 and 76.97, based on the sample data. This means if we repeated the sampling process and calculated the confidence interval for each sample, we would expect 90% of the intervals to contain the true population mean.

# %% [markdown]
# ### Q6. Use Python to plot the chi-square distribution with 10 degrees of freedom. Label the axes and shade the area corresponding to a chi-square statistic of 15.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import chi2

# Define the degrees of freedom
df = 10

# Create the x values for the chi-square distribution
x = np.linspace(0, 30, 500)

# Calculate the y values for the chi-square distribution
y = chi2.pdf(x, df)

# Create the plot
plt.plot(x, y)

# Shade the area corresponding to a chi-square statistic of 15
x_fill = np.linspace(15, 30, 100)
y_fill = chi2.pdf(x_fill, df)
plt.fill_between(x_fill, y_fill, color='orange')

# Label the axes
plt.xlabel('Chi-Square Statistic')
plt.ylabel('Probability Density')

# Show the plot
plt.show()

# %% [markdown]
# ### Q7. A random sample of 1000 people was asked if they preferred Coke or Pepsi. Of the sample, 520 preferred Coke. Calculate a 99% confidence interval for the true proportion of people in the population who prefer Coke.

# %%
import math

# Sample size and number of people who preferred Coke in the sample
n = 1000
x = 520

# Sample proportion and standard error
p_hat = x / n
se = math.sqrt((p_hat * (1 - p_hat)) / n)

# Z-score for 99% confidence level
z = 2.576

# Calculate confidence interval
CI = (p_hat + z * se, p_hat - z * se)

# Print confidence interval
print("99% Confidence Interval: ({:.3f}, {:.3f})".format(CI[1], CI[0]))
# Out:
# 99% Confidence Interval: (0.479, 0.561)

# %% [markdown]
# ###### The 99% confidence interval for the true proportion of people in the population who prefer Coke is (0.479, 0.561). This means that we can be 99% confident that the true proportion of people in the population who prefer Coke lies between 47.9% and 56.1%.

# %% [markdown]
# ### Q8. A researcher hypothesizes that a coin is biased towards tails. They flip the coin 100 times and observe 45 tails. Conduct a chi-square goodness of fit test to determine if the observed frequencies match the expected frequencies of a fair coin. Use a significance level of 0.05.

# %% [markdown]
# #### To conduct a chi-square goodness of fit test to determine if the observed frequencies of a coin being biased towards tails match the expected frequencies of a fair coin, given that the coin was flipped 100 times and 45 tails were observed, we can follow these steps:
#
# ###### Define the null and alternative hypotheses:
#
# ##### Null hypothesis: The coin is fair, and the observed frequencies match the expected frequencies.
# ##### Alternative hypothesis: The coin is biased towards tails, and the observed frequencies do not match the expected frequencies.
# ###### Determine the expected frequencies under the null hypothesis. For a fair coin, the expected frequency of tails is 50 and the expected frequency of heads is also 50.
#
# ###### Calculate the test statistic, which is the sum of the squared differences between the observed and expected frequencies divided by the expected frequencies, and has a chi-square distribution with 1 degree of freedom.
#
# ###### Determine the p-value associated with the test statistic using a chi-square distribution table or a statistical software.
#
# ###### Compare the p-value to the significance level. If the p-value is less than or equal to the significance level, reject the null hypothesis and conclude that there is evidence of a bias towards tails. Otherwise, fail to reject the null hypothesis.
#
# ##### Here's the Python code to conduct the chi-square goodness of fit test:

# %%
import scipy.stats as stats

# Observed frequencies
observed = [45, 55]

# Expected frequencies under the null hypothesis
expected = [50, 50]

# Calculate the test statistic and p-value
test_statistic, p_value = stats.chisquare(observed, expected)

# Print the test statistic and p-value
print("Test Statistic:", test_statistic)
print("p-value:", p_value)

# Compare the p-value to the significance level
alpha = 0.05
if p_value <= alpha:
    print("Reject the null hypothesis. There is evidence of a bias towards tails.")
else:
    print("Fail to reject the null hypothesis. The coin may be fair.")
# Out:
# Test Statistic: 1.0
# p-value: 0.31731050786291115
# Fail to reject the null hypothesis. The coin may be fair.

# %% [markdown]
# ###### The test statistic is 1.0 and the p-value is 0.317, which is greater than the significance level of 0.05. Therefore, we fail to reject the null hypothesis and conclude that the coin may be fair. There is not enough evidence to support the alternative hypothesis that the coin is biased towards tails.

# %% [markdown]
# ### Q9. A study was conducted to determine if there is an association between smoking status (smoker or non-smoker) and lung cancer diagnosis (yes or no). The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between smoking status and lung cancer diagnosis.
# ![Screenshot%202023-03-17%20113649.jpg](attachment:Screenshot%202023-03-17%20113649.jpg)
# ### Use a significance level of 0.05.

# %%
import numpy as np
import scipy.stats as stats

# Observed frequencies
observed = np.array([[60, 140], [30, 170]])

# Calculate the expected frequencies under the assumption of independence
row_totals = observed.sum(axis=1)
col_totals = observed.sum(axis=0)
total = observed.sum()
expected = np.outer(row_totals, col_totals) / total

# Calculate the test statistic and p-value
test_statistic, p_value, dof, expected = stats.chi2_contingency(observed)

# Print the test statistic and p-value
print("Test Statistic:", test_statistic)
print("p-value:", p_value)

# Compare the p-value to the significance level
alpha = 0.05
if p_value <= alpha:
    print("Reject the null hypothesis. There is evidence of an association between smoking status and lung cancer diagnosis.")
else:
    print("Fail to reject the null hypothesis. There may not be an association between smoking status and lung cancer diagnosis.")
# Out:
# Test Statistic: 12.057347670250895
# p-value: 0.0005158863863703744
# Reject the null hypothesis. There is evidence of an association between smoking status and lung cancer diagnosis.

# %% [markdown]
# ###### The test statistic is 12.05 and the p-value is 0.00051, which is less than the significance level of 0.05. Therefore, we reject the null hypothesis and conclude that there is evidence of an association between smoking status and lung cancer diagnosis.

# %% [markdown]
# ### Q10. A study was conducted to determine if the proportion of people who prefer milk chocolate, dark chocolate, or white chocolate is different in the U.S. versus the U.K. A random sample of 500 people from the U.S. and a random sample of 500 people from the U.K. were surveyed. The results are shown in the contingency table below. Conduct a chi-square test for independence to determine if there is a significant association between chocolate preference and country of origin.
# ![Screenshot%202023-03-17%20084457.jpg](attachment:Screenshot%202023-03-17%20084457.jpg)
# ### Use a significance level of 0.01.

# %% [markdown]
# #### To conduct a chi-square test for independence, we first need to set up the null and alternative hypotheses:
#
# ###### Null hypothesis: There is no association between chocolate preference and country of origin.
# ###### Alternative hypothesis: There is an association between chocolate preference and country of origin.
#
# #### Next, we calculate the expected frequencies for each cell under the assumption that the null hypothesis is true. We can do this by multiplying the row total and column total for each cell and dividing by the total sample size:
#
# ###### Milk Chocolate  Dark Chocolate  White Chocolate   Row Total
# ##### U.S. (n=500) 180.56     147.22     172.22     500
# ##### U.K. (n=500) 244.44    199.78     55.56       500
# ##### Column Total 425       347          227         1000
#
# #### We can then calculate the chi-square statistic:
#
# ###### chi-square = Σ((observed frequency - expected frequency)^2 / expected frequency)
#
# ###### Using a significance level of 0.01 and 2 degrees of freedom (since there are 3 rows and 3 columns), the critical value from the chi-square distribution table is 9.210.
#
# ###### The calculated chi-square statistic is:
#
# ###### chi-square = ((200-180.56)^2/180.56) + ((150-147.22)^2/147.22) + ((150-172.22)^2/172.22) + ((225-244.44)^2/244.44) + ((175-199.78)^2/199.78) + ((100-55.56)^2/55.56)
# ###### chi-square = 24.28
#
# ##### Since the calculated chi-square value of 24.28 is greater than the critical value of 9.210, we reject the null hypothesis and conclude that there is a significant association between chocolate preference and country of origin at a significance level of 0.01.
